# %%
import pandas as pd
import numpy as np

# %% [markdown]
# movies=pd.read_csv('tmdb_5000_movies.csv')
# credits=pd.read_csv('tmdb_5000_credits.csv')

# %%
movies=pd.read_csv('tmdb_5000_movies.csv') 
credits=pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies=movies.merge(credits,on='title')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.shape
# Out:
# (4809, 23)

# %%
movies=movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %% [markdown]
# movies.head()

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %% [markdown]
# ### Removing rows having null values

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %% [markdown]
# ### checking for duplict rows

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies['genres']
# Out:
# 0       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#                               ...
# 4804    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805    [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806    [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807                                                   []
# 4808                  [{"id": 99, "name": "Documentary"}]
# Name: genres, Length: 4806, dtype: object

# %% [markdown]
# ### Reformating genres,keywords,cast,crew

# %%
# convert genres to ["Action"Comedy"...]

# %%
import ast #for converting string to list

# %%
def convert(obj): #function that maps each genre and extracts name fron each object...
    A=[]
    for x in ast.literal_eval(obj):
        A.append(x['name'])
    return A

# %%
movies['genres']=movies['genres'].apply(convert)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['keywords']=movies['keywords'].apply(convert) #similarly filtering keywords

# %%
movies['keywords']
# Out:
# 0       [culture clash, future, space war, space colon...
# 1       [ocean, drug abuse, exotic island, east india ...
# 2       [spy, based on novel, secret agent, sequel, mi...
# 3       [dc comics, crime fighter, terrorist, secret i...
# 4       [based on novel, mars, medallion, space travel...
#                               ...
# 4804    [united states–mexico barrier, legs, arms, pap...
# 4805                                                   []
# 4806    [date, love at first sight, narration, investi...
# 4807                                                   []
# 4808            [obsession, camcorder, crush, dream girl]
# Name: keywords, Length: 4806, dtype: object

# %%
movies['cast']
# Out:
# 0       [{"cast_id": 242, "character": "Jake Sully", "...
# 1       [{"cast_id": 4, "character": "Captain Jack Spa...
# 2       [{"cast_id": 1, "character": "James Bond", "cr...
# 3       [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4       [{"cast_id": 5, "character": "John Carter", "c...
#                               ...
# 4804    [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805    [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806    [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807    [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808    [{"cast_id": 3, "character": "Herself", "credi...
# Name: cast, Length: 4806, dtype: object

# %%
def convert3(obj):#we will be taking only first 3 names from cast array
    A = []
    counter = 0
    for x in ast.literal_eval(obj):
        if counter != 3:
            A.append(x['name'])
            counter+=1
        else:
            break
    return A

# %%
movies['cast']= movies['cast'].apply(convert3)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
def findDir(obj):#extracting names from crew where job is director
    A=[]
    for x in ast.literal_eval(obj):
        if x['job'] =='Director':
            A.append(x['name'])
            break
    return A

# %%
movies['crew']=movies['crew'].apply(findDir)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
#converting overview from string format to list so that we can concatenate with others
movies['overview']=movies['overview'].apply(lambda x: x.split())

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %% [markdown]
# #### Removing spaces

# %%
#removing spaces between words Sam Worthington-->SamWorthington
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %% [markdown]
# ### forming tags

# %%
movies['tags']=movies['overview']+movies['genres']+movies['keywords']+movies['cast']+movies['crew']

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
#framing new dataset with required columns,now we dont need genres,overview..etc 
#as we have tags.
new_dataset=movies[['movie_id','title','tags']]

# %%
new_dataset.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
#converting list to string so that we can do s=text vectorization.
new_dataset['tags']=new_dataset['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\VIKAS REDDY\AppData\Local\Temp\ipykernel_6004\2010674294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataset['tags']=new_dataset['tags'].apply(lambda x:" ".join(x))

# %%
new_dataset.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
#convert tags into lowercase
new_dataset['tags']=new_dataset['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\VIKAS REDDY\AppData\Local\Temp\ipykernel_6004\3509159001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataset['tags']=new_dataset['tags'].apply(lambda x:x.lower())

# %%
new_dataset['tags'][0]
# Out:
# 'in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d samworthington zoesaldana sigourneyweaver jamescameron'

# %% [markdown]
# STEMMING OF TAGS

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y=[]
    
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
stem('in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d samworthington zoesaldana sigourneyweaver jamescameron')
# Out:
# 'in the 22nd century, a parapleg marin is dispatch to the moon pandora on a uniqu mission, but becom torn between follow order and protect an alien civilization. action adventur fantasi sciencefict cultureclash futur spacewar spacecoloni societi spacetravel futurist romanc space alien tribe alienplanet cgi marin soldier battl loveaffair antiwar powerrel mindandsoul 3d samworthington zoesaldana sigourneyweav jamescameron'

# %%
new_dataset['tags']=new_dataset['tags'].apply(stem)
# Out:
# C:\Users\VIKAS REDDY\AppData\Local\Temp\ipykernel_6004\1283114390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataset['tags']=new_dataset['tags'].apply(stem)

# %%
new_dataset['title']=='Avatar'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4804    False
# 4805    False
# 4806    False
# 4807    False
# 4808    False
# Name: title, Length: 4806, dtype: bool

# %% [markdown]
# CREATING VECTORS

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors = cv.fit_transform(new_dataset['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
cv.get_feature_names()
# Out:
# C:\Users\VIKAS REDDY\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['000',
#  '007',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '17th',
#  '18',
#  '18th',
#  '18thcenturi',
#  '19',
#  '1910',
#  '1920',
#  '1930',
#  '1940',
#  '1944',
#  '1950',
#  '1950s',
#  '1960',
#  '1960s',
#  '1970',
#  '1970s',
#  '1971',
#  '1974',
#  '1976',
#  '1980',
#  '1985',
#  '1990',
#  '1999',
#  '19th',
#  '19thcenturi',
#  '20',
#  '200',
#  '2003',
#  '2009',
#  '20th',
#  '21st',
#  '23',
#  '24',
#  '25',
#  '30',
#  '300',
#  '3d',
#  '40',
#  '50',
#  '500',
#  '60',
#  '70',
#  '80',
#  'aaron',
#  'aaroneckhart',
#  'abandon',
#  'abduct',
#  'abigailbreslin',
#  'abil',
#  'abl',
# ...

# %%
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors);
distances=euclidean_distances(vectors,vectors)

# %%
distances[0]
# Out:
# array([0.        , 8.1240384 , 8.        , ..., 9.2736185 , 9.32737905,
#        9.        ])

# %%
similarity[1]
# Out:
# array([0.08346223, 1.        , 0.06063391, ..., 0.02378257, 0.        ,
#        0.02615329])

# %%
new_dataset[new_dataset['title']=='Sardaarji'].index[0]
# Out:
# 3999

# %%
sorted(list(enumerate(distances[90])),key=lambda x:x[1])
# Out:
# [(90, 0.0),
#  (4461, 5.477225575051661),
#  (4405, 5.5677643628300215),
#  (3527, 5.656854249492381),
#  (3998, 5.656854249492381),
#  (4641, 5.656854249492381),
#  (2278, 5.744562646538029),
#  (4777, 5.744562646538029),
#  (3550, 5.830951894845301),
#  (3787, 5.830951894845301),
#  (1862, 5.916079783099616),
#  (2232, 5.916079783099616),
#  (3296, 5.916079783099616),
#  (3804, 5.916079783099616),
#  (4253, 5.916079783099616),
#  (4409, 5.916079783099616),
#  (649, 6.0),
#  (2466, 6.0),
#  (2544, 6.0),
#  (3082, 6.0),
#  (3552, 6.0),
#  (4053, 6.0),
#  (4293, 6.0),
#  (4494, 6.0),
#  (4583, 6.0),
#  (4636, 6.0),
#  (381, 6.082762530298219),
#  (2237, 6.082762530298219),
#  (2856, 6.082762530298219),
#  (3002, 6.082762530298219),
#  (3359, 6.082762530298219),
#  (3919, 6.082762530298219),
#  (4173, 6.082762530298219),
#  (4246, 6.082762530298219),
#  (4309, 6.082762530298219),
#  (4537, 6.082762530298219),
#  (4615, 6.082762530298219),
#  (4793, 6.082762530298219),
# ...

# %%
sorted(list(enumerate(similarity[0])),key=lambda x:x[1],reverse=True)
# Out:
# [(0, 1.0000000000000002),
#  (1216, 0.28676966733820225),
#  (2409, 0.26901379342448517),
#  (3730, 0.2605130246476754),
#  (507, 0.255608593705383),
#  (539, 0.25038669783359574),
#  (582, 0.24511108480187255),
#  (1204, 0.24455799402225925),
#  (1194, 0.2367785320221084),
#  (61, 0.23179316248638276),
#  (778, 0.23174488732966073),
#  (4048, 0.2278389747471728),
#  (1920, 0.2252817784447915),
#  (2786, 0.21853668936906193),
#  (172, 0.21239769762143662),
#  (972, 0.2108663315950723),
#  (322, 0.2105263157894737),
#  (2333, 0.20443988269091456),
#  (3608, 0.20437977982832192),
#  (260, 0.20395079136182276),
#  (151, 0.2029530274475215),
#  (4192, 0.2029530274475215),
#  (1444, 0.20277677641345318),
#  (74, 0.2024645717996314),
#  (1089, 0.2020475485519274),
#  (3675, 0.1979082783981174),
#  (973, 0.19767387315371682),
#  (577, 0.1976738731537168),
#  (47, 0.19672236884115843),
#  (2971, 0.1925214071641298),
#  (942, 0.19134594929397597),
#  (495, 0.19088542889273336),
# ...

# %%
sorted(list(enumerate(distances[0])),key=lambda x:x[1])[1:3]
# Out:
# [(4405, 6.082762530298219), (3527, 6.324555320336759)]

# %%
new_dataset.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a parapleg marin is dispa...
# 1  captain barbossa, long believ to be dead, ha c...
# 2  a cryptic messag from bond’ past send him on a...
# 3  follow the death of district attorney harvey d...
# 4  john carter is a war-weary, former militari ca...

# %%
new_dataset.iloc[new_dataset[new_dataset['title']=="The Dark Knight Rises"].index[0]]
# Out:
# movie_id                                                49026
# title                                   The Dark Knight Rises
# tags        follow the death of district attorney harvey d...
# Name: 3, dtype: object

# %%
def crecommend(movie):
    movie_index=new_dataset[new_dataset['title']== movie].index[0]
    node_distances=similarity[movie_index]
    recommended_list=sorted(list(enumerate(node_distances)),key=lambda x:x[1],reverse=True)[0:6]
    temp=[];
    for i in recommended_list:
            temp.append(new_dataset.iloc[i[0]].title)
    return temp

# %%
def recommend(movie):
    movie_index=new_dataset[new_dataset['title']== movie].index[0]
    node_distances=distances[movie_index]
    recommended_list=sorted(list(enumerate(node_distances)),key=lambda x:x[1])[0:6]
    temp=[];
    for i in recommended_list:
            temp.append(new_dataset.iloc[i[0]].title)
    return temp

# %%
crecommend("Avatar")
# Out:
# ['Avatar',
#  'Aliens vs Predator: Requiem',
#  'Aliens',
#  'Falcon Rising',
#  'Independence Day',
#  'Titan A.E.']

# %%
recommend("Avatar")
# Out:
# ['Avatar',
#  'The Helix... Loaded',
#  'Khiladi 786',
#  'Harrison Montgomery',
#  "Amidst the Devil's Wings",
#  'Sardaarji']

# %%
recommend("avatar")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [62], line 1
# ----> 1 recommend("avatar")
#
# Cell In [58], line 2, in recommend(movie)
#       1 def recommend(movie):
# ----> 2     movie_index=new_dataset[new_dataset['title']== movie].index[0]
#       3     node_distances=distances[movie_index]
#       4     recommended_list=sorted(list(enumerate(node_distances)),key=lambda x:x[1])[0:3]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5358, in Index.__getitem__(self, key)
#    5355 if is_integer(key) or is_float(key):
#    5356     # GH#44051 exclude bool, which would return a 2d ndarray
#    5357     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5358     return getitem(key)
#    5360 if isinstance(key, slice):
#    5361     # This case is separated from the conditional above to avoid
# ...

# %%
new_dataset.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a parapleg marin is dispa...
# 1  captain barbossa, long believ to be dead, ha c...
# 2  a cryptic messag from bond’ past send him on a...
# 3  follow the death of district attorney harvey d...
# 4  john carter is a war-weary, former militari ca...

# %%
crecommend("Pirates of the Caribbean: At World's End")
# Out:
# ["Pirates of the Caribbean: At World's End",
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Life of Pi',
#  '20,000 Leagues Under the Sea']

# %%
recommend("Pirates of the Caribbean: At World's End")
# Out:
# ["Pirates of the Caribbean: At World's End",
#  'The Helix... Loaded',
#  'Khiladi 786',
#  'Harrison Montgomery',
#  "Amidst the Devil's Wings",
#  "Pirates of the Caribbean: Dead Man's Chest"]

# %%
crecommend("The Dark Knight Rises")
# Out:
# ['The Dark Knight Rises',
#  'The Dark Knight',
#  'Batman Returns',
#  'Batman',
#  'Batman Forever',
#  'Batman Begins']

# %%
recommend("The Dark Knight Rises")
# Out:
# ['The Dark Knight Rises',
#  'Nighthawks',
#  "Amidst the Devil's Wings",
#  'Batman',
#  'Exiled',
#  'Mi America']

# %%
recommend("Spectre")
# Out:
# ['Spectre',
#  "Amidst the Devil's Wings",
#  'The Helix... Loaded',
#  'Khiladi 786',
#  'Harrison Montgomery',
#  'Sardaarji']

# %%
crecommend("Spectre")
# Out:
# ['Spectre',
#  'Quantum of Solace',
#  'Skyfall',
#  'Never Say Never Again',
#  'From Russia with Love',
#  'Octopussy']

# %%
recommend("John Carter")
# Out:
# ['John Carter',
#  'The Helix... Loaded',
#  'Khiladi 786',
#  'Harrison Montgomery',
#  "Amidst the Devil's Wings",
#  'Devil']

# %%
crecommend("John Carter")
# Out:
# ['John Carter',
#  'Riddick',
#  'Krrish',
#  'The Other Side of Heaven',
#  'The Legend of Hercules',
#  'Get Carter']

# %%
recommend("Batman Begins")
# Out:
# ['Batman Begins',
#  "Amidst the Devil's Wings",
#  'The Loss of Sexual Innocence',
#  'Son of God',
#  'The Helix... Loaded',
#  'Batman']

# %%
crecommend("Batman Begins")
# Out:
# ['Batman Begins',
#  'The Dark Knight',
#  'Batman',
#  'Batman',
#  'The Dark Knight Rises',
#  '10th & Wolf']
